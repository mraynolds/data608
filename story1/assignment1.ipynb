# %% [markdown]
# # Infrastructure Investments & Jobs Act Funding

# %%
# import packages

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import openpyxl
import requests
from io import BytesIO

# %%
#check working directory
os.getcwd()
# Out:
# '/Users/field/Desktop/CUNY/data_608/data_608_assignments/assignment1'

# %%
#import data
iija = pd.DataFrame(pd.read_excel('data/IIJA FUNDING AS OF MARCH 2023.xlsx'))

# %%
#check data head
iija.head()
# Out:
#   State, Teritory or Tribal Nation  Total (Billions)
# 0                          ALABAMA            3.0000
# 1                           ALASKA            3.7000
# 2                   AMERICAN SAMOA            0.0686
# 3                          ARIZONA            3.5000
# 4                         ARKANSAS            2.8000

# %%
# clean data
iija = iija.rename(columns = {'State, Teritory or Tribal Nation': 'State'})
iija['State'] = iija['State'].astype(str).str.strip().str.lower().str.replace(' ', '_')
iija.at[8,'State'] = 'delaware'
iija
# Out:
#                        State  Total (Billions)
# 0                    alabama            3.0000
# 1                     alaska            3.7000
# 2             american_samoa            0.0686
# 3                    arizona            3.5000
# 4                   arkansas            2.8000
# 5                 california           18.4000
# 6                   colorado            3.2000
# 7                connecticut            2.5000
# 8                   delaware            0.7920
# 9       district_of_columbia            1.1000
# 10                   florida            8.2000
# 11                   georgia            5.0000
# 12                      guam            0.1426
# 13                    hawaii            1.0000
# 14                     idaho            1.2000
# 15                  illinois            8.4000
# 16                   indiana            3.4000
# 17                      iowa            2.4000
# 18                    kansas            1.5000
# 19                  kentucky            3.9000
# 20                 louisiana            4.3000
# 21                     maine            1.1000
# 22                  maryland            2.7000
# 23             massachusetts            3.6000
# 24                  michigan            5.2000
# 25                 minnesota            2.7000
# 26               mississippi            2.3000
# 27                  missouri            3.8000
# 28                   montana            3.3000
# 29                  nebraska            1.3000
# 30                    nevada            1.7000
# 31             new_hampshire            0.7518
# 32                new_jersey            5.1000
# 33                new_mexico            2.6000
# 34                  new_york           10.1000
# 35            north_carolina            4.5000
# 36              north_dakota            1.8000
# 37  northern_mariana_islands            0.0833
# 38                      ohio            6.6000
# 39                  oklahoma            2.9000
# 40                    oregon            2.3000
# 41              pennsylvania            8.1000
# 42               puerto_rico            0.9937
# 43              rhode_island            1.1000
# 44            south_carolina            2.3000
# 45              south_dakota            1.3000
# 46                 tennessee            3.7000
# 47                     texas           14.2000
# 48        tribal_communities            3.0000
# 49         us_virgin_islands            0.1483
# 50                      utah            1.8000
# 51                   vermont            0.8521
# 52                  virginia            4.5000
# 53                washington            4.0000
# 54             west_virginia            2.0000
# 55                 wisconsin            2.8000
# 56                   wyoming            2.3000

# %%
# import population data
url = 'https://www2.census.gov/programs-surveys/popest/tables/2020-2025/state/totals/NST-EST2025-POP.xlsx'

response = requests.get(url)
response.raise_for_status()

population = pd.DataFrame(pd.read_excel(BytesIO(response.content), skiprows=3))

# %%
population.head(60)
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0                                       United States  331516113.0
# 1                                           Northeast   57617560.0
# 2                                             Midwest   68999462.0
# 3                                               South  126281605.0
# 4                                                West   78617486.0
# 5                                            .Alabama    5025437.0
# 6                                             .Alaska     733383.0
# 7                                            .Arizona    7158104.0
# 21    2977220.0
# 22    4606864.0
# 23    4618189.0
# 24    1414874.0
# 25    6265347.0
# 26    7154084.0
# 27   10127884.0
# 28    5830405.0
# 29    2954160.0
# 30    6270541.0
# 31    1144694.0
# 32    2018006.0
# 33    3282188.0
# 34    1415342.0
# 35    9548215.0
# 36    2125498.0
# 37   20002427.0
# 38   11197968.0
# 39     799358.0
# 40   11900510.0
# 41    4123288.0
# 42    4273586.0
# 43   13059432.0
# 44    1114521.0
# 45    5570274.0
# 46     935094.0
# 47    7315076.0
# 48   31709821.0
# 49    3538904.0
# 50     644663.0
# 51    8880107.0
# 52    8001020.0
# 53    1766147.0
# 54    5972787.0
# 55     588753.0
# 56          NaN
# 57    3184835.0
# 58          NaN
# 59          NaN

# %%
# clean population data

rows_to_drop = [0,1,2,3,4,56,58,59,60,61,62,63]
population = population.drop(index=rows_to_drop).reset_index().drop('index', axis=1)

# %%
# continue cleaning population data

population = population.rename(columns={'Unnamed: 0':'State',2023:'Population'})
population = population.drop(columns=['Unnamed: 1',2020,2021,2022,2024,2025])

# %%
# population data for territories from the following url: https://www.census.gov/newsroom/press-releases/2020/2020-island-areas-populations.html

terr_pop = {'State': ['american_samoa', 'guam','northern_mariana_islands','us_virgin_islands'],
            'Population':[55519,159385,53883,106405]}
terr_pop = pd.DataFrame(terr_pop)

# %%
# continue to clean and append population data

population['State'] = population['State'].astype(str).str.lstrip('.').str.strip().str.lower().str.replace(' ', '_')
population = pd.concat([population,terr_pop]).sort_values(by='State').reset_index(drop=True)
population.head(20)
# Out:
#                    State  Population
# 0                alabama   5117850.0
# 1                 alaska    734654.0
# 2         american_samoa     55519.0
# 3                arizona   7452073.0
# 4               arkansas   3069856.0
# 5             california  39181667.0
# 6               colorado   5912240.0
# 7            connecticut   3641369.0
# 8               delaware   1035354.0
# 9   district_of_columbia    682559.0
# 10               florida  22929248.0
# 11               georgia  11063669.0
# 12                  guam    159385.0
# 13                hawaii   1434950.0
# 14                 idaho   1970497.0
# 15              illinois  12633389.0
# 16               indiana   6881373.0
# 17                  iowa   3214739.0
# 18                kansas   2949749.0
# 19              kentucky   4549953.0

# %%
# import voting data

url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vS3Z8Rq9xqOLISwoKdK0n6CFLBuPSCoXbbLeY8vhi-rzFS3ZFNEtR0BCdEbHcS-2Tlh5aPcnZbwBLao/pub?output=csv'

response = requests.get(url)
response.raise_for_status()

votes = pd.DataFrame(pd.read_csv(BytesIO(response.content)))

# %%
# clean voting data

rows_to_drop = [0,1,2,3,]
votes = votes.drop(rows_to_drop).reset_index().drop(columns = 'index')

# %%
# take a look at voting data

votes
# Out:
#                     state called final   dem_votes  rep_votes other_votes  \
# 0                 Arizona      D   Yes   1,672,143  1,661,686      53,497
# 1                 Florida      R   Yes   5,297,045  5,668,731     101,680
# 2                 Georgia      D   Yes   2,473,633  2,461,854      62,229
# 3                    Iowa      R   Yes     759,061    897,672      34,138
# 4      Maine 2nd District      R   Yes     168,696    196,692      10,961
# 5                Michigan      D   Yes   2,804,040  2,649,852      85,410
# 6               Minnesota      D   Yes   1,717,077  1,484,065      76,029
# 7   Nebraska 2nd District      D   Yes     176,468    154,377       6,909
# 8                  Nevada      D   Yes     703,486    669,890      32,000
# 9           New Hampshire      D   Yes     424,921    365,654      15,607
# 10         North Carolina      R   Yes   2,684,292  2,758,775      81,737
# 11                   Ohio      R   Yes   2,679,165  3,154,834      88,203
# 12           Pennsylvania      D   Yes   3,458,229  3,377,674      79,380
# 13                  Texas      R   Yes   5,259,126  5,890,347     165,583
# 14              Wisconsin      D   Yes   1,630,866  1,610,184      56,991
# 15      Non-Battlegrounds    NaN   NaN         NaN        NaN         NaN
# 16                Alabama      R   Yes     849,624  1,441,170      32,488
# 17                 Alaska      R   Yes     153,778    189,951      15,801
# 18               Arkansas      R   Yes     423,932    760,647      34,490
# 19             California      D   Yes  11,110,250  6,006,429     384,192
# 20               Colorado      D   Yes   1,804,352  1,364,607      87,993
# 21            Connecticut      D   Yes   1,080,831    714,717      28,309
# 22               Delaware      D   Yes     296,268    200,603       7,475
# 23   District of Columbia      D   Yes     317,323     18,586       8,447
# 24                 Hawaii      D   Yes     366,130    196,864      11,475
# 25                  Idaho      R   Yes     287,021    554,119      26,091
# 26               Illinois      D   Yes   3,471,915  2,446,891     114,938
# 27                Indiana      R   Yes   1,242,413  1,729,516      61,183
# 28                 Kansas      R   Yes     570,323    771,406      30,574
# 29               Kentucky      R   Yes     772,474  1,326,646      37,648
# 30              Louisiana      R   Yes     856,034  1,255,776      36,252
# 31                  Maine      D   Yes     435,072    360,737      23,652
# 32     Maine 1st District      D   Yes     266,376    164,045      12,691
# 33               Maryland      D   Yes   1,985,023    976,414      75,593
# 34          Massachusetts      D   Yes   2,382,202  1,167,202      81,998
# 35            Mississippi      R   Yes     539,508    756,789      17,597
# 36               Missouri      R   Yes   1,253,014  1,718,736      54,212
# 37                Montana      R   Yes     244,786    343,602      15,286
# 38               Nebraska      R   Yes     374,583    556,846      20,283
# 39  Nebraska 1st District      R   Yes     132,261    180,290       7,495
# 40  Nebraska 3rd District      R   Yes      65,854    222,179       5,879
# 41             New Jersey      D   Yes   2,608,335  1,883,274      57,744
# 42             New Mexico      D   Yes     501,614    401,894      20,457
# 43               New York      D   Yes   5,244,886  3,251,997     119,978
# 44           North Dakota      R   Yes     114,902    235,595      11,322
# 45               Oklahoma      R   Yes     503,890  1,020,280      36,529
# 46                 Oregon      D   Yes   1,340,383    958,448      75,490
# 47           Rhode Island      D   Yes     307,486    199,922      10,349
# 48         South Carolina      R   Yes   1,091,541  1,385,103      36,685
# 49           South Dakota      R   Yes     150,471    261,043      11,095
# 50              Tennessee      R   Yes   1,143,711  1,852,475      57,665
# 51                   Utah      R   Yes     560,282    865,140      62,867
# 52                Vermont      D   Yes     242,820    112,704      11,904
# 53               Virginia      D   Yes   2,413,568  1,962,430      84,526
# 54             Washington      D   Yes   2,369,612  1,584,651     133,368
# 55          West Virginia      R   Yes     235,984    545,382      13,286
# 56                Wyoming      R   Yes      73,491    193,559       9,715
#
#    dem_percent rep_percent other_percent dem_this_margin  ... stateid    EV  \
# 0        49.4%       49.1%          1.6%            0.3%  ...      AZ  11.0
# 34  10.0  5.0       25.0     895.0     169.0          NaN     0.271967
# 35   5.0  1.0       28.0     617.0     427.0          NaN    -0.178262
# 36   5.0  3.0       29.0     557.0     305.0          NaN    -0.186371
# 37   3.0  5.0       30.0     289.0      95.0          NaN    -0.204227
# 38   4.0  3.0       31.0     438.0     238.0          NaN    -0.250486
# 39  12.0  7.0      103.0     438.0     238.0          NaN    -0.207198
# 40  12.0  5.0      105.0     438.0     238.0          NaN    -0.541881
# 41   9.0  4.0       34.0     865.0     231.0          NaN     0.141027
# 42   3.0  2.0       35.0     309.0     385.0          NaN     0.082131
# 43   9.0  5.0       36.0     838.0     168.0          NaN     0.224905
# 44   4.0  5.0       38.0     426.0      97.0          NaN    -0.357289
# 45   3.0  1.0       40.0     477.0     377.0          NaN    -0.363912
# 46   1.0  4.0       41.0      97.0     134.0          NaN     0.109778
# 47  11.0  4.0       44.0     904.0     183.0          NaN     0.155085
# 48   8.0  2.0       45.0     783.0     394.0          NaN    -0.142659
# 49   4.0  4.0       46.0     430.0     168.0          NaN    -0.297933
# 50   6.0  2.0       47.0     670.0     360.0          NaN    -0.260057
# 51   2.0  3.0       49.0     225.0     266.0          NaN    -0.180793
# 52  10.0  6.0       50.0     873.0     134.0          NaN     0.264084
# 53   8.0  3.0       51.0     809.0     299.0          NaN     0.053212
# 54   1.0  5.0       53.0     128.0      58.0          NaN     0.157060
# 55   7.0  3.0       54.0     765.0     284.0          NaN    -0.420727
# 56   3.0  4.0       56.0     306.0     187.0          NaN    -0.462953
#
#     Total 2016 Votes
# 0          2,573,165
# 1          9,420,039
# 2          4,092,373
# 3          1,566,031
# 4            353,416
# 5          4,799,284
# 6          2,944,813
# 7            291,680
# 8          1,125,385
# 9            744,158
# 10         4,741,564
# 11         5,496,487
# 12         6,115,402
# 13         8,969,226
# 14         2,976,150
# 15               NaN
# 16         2,123,372
# 17           318,608
# 18         1,130,635
# 19        14,181,595
# 20         2,780,220
# 21         1,644,920
# 22           441,590
# 23           311,268
# 24           428,937
# 25           690,255
# 26         5,536,424
# 27         2,734,958
# 28         1,184,402
# 29         1,924,149
# 30         2,029,032
# 31           747,927
# 32           394,329
# 33         2,781,446
# 34         3,325,046
# 35         1,209,357
# 36         2,808,605
# 37           497,147
# 38           844,289
# 39           282,338
# 40           270,109
# 41         3,874,046
# 42           798,318
# 43         7,721,453
# 44           344,360
# 45         1,452,992
# 46         2,001,336
# 47           464,144
# 48         2,103,027
# 49           370,093
# 50         2,508,027
# 51         1,131,430
# 52           315,067
# 53         3,982,752
# 54         3,365,644
# 55           713,051
# 56           255,849
#
# [57 rows x 22 columns]

# %%
# continue to clean voting data
votes = votes.sort_values(by='state', ascending=True).reset_index(drop=True)
rows_to_drop = [20, 21, 30, 31, 32, 38]
votes = votes.drop(rows_to_drop).reset_index(drop=True)

# %%
# continue to clean voting data

num_columns = ['dem_votes', 'rep_votes', 'other_votes','Total 2016 Votes']
pct_columns = ['dem_percent', 'rep_percent', 'other_percent', 'dem_this_margin', 'margin_shift', 'vote_change']
votes = votes.rename(columns={'state':'State'})
votes['State'] = votes['State'].astype(str).str.strip().str.lower().str.replace(' ','_')
votes[num_columns] = (votes[num_columns].replace(',' , '', regex=True).astype(float))
votes[pct_columns] = (votes[pct_columns].replace('%','', regex=True).astype(float))/100
votes.head(60)
# Out:
#                    State called final   dem_votes  rep_votes  other_votes  \
# 0                alabama      R   Yes    849624.0  1441170.0      32488.0
# 1                 alaska      R   Yes    153778.0   189951.0      15801.0
# 2                arizona      D   Yes   1672143.0  1661686.0      53497.0
# 3               arkansas      R   Yes    423932.0   760647.0      34490.0
# 4             california      D   Yes  11110250.0  6006429.0     384192.0
# 5               colorado      D   Yes   1804352.0  1364607.0      87993.0
# 6            connecticut      D   Yes   1080831.0   714717.0      28309.0
# 7               delaware      D   Yes    296268.0   200603.0       7475.0
# 8   district_of_columbia      D   Yes    317323.0    18586.0       8447.0
# 9                florida      R   Yes   5297045.0  5668731.0     101680.0
# 10               georgia      D   Yes   2473633.0  2461854.0      62229.0
# 11                hawaii      D   Yes    366130.0   196864.0      11475.0
# 12                 idaho      R   Yes    287021.0   554119.0      26091.0
# 13              illinois      D   Yes   3471915.0  2446891.0     114938.0
# 14               indiana      R   Yes   1242413.0  1729516.0      61183.0
# 15                  iowa      R   Yes    759061.0   897672.0      34138.0
# 16                kansas      R   Yes    570323.0   771406.0      30574.0
# 17              kentucky      R   Yes    772474.0  1326646.0      37648.0
# 18             louisiana      R   Yes    856034.0  1255776.0      36252.0
# 19                 maine      D   Yes    435072.0   360737.0      23652.0
# 20              maryland      D   Yes   1985023.0   976414.0      75593.0
# 21         massachusetts      D   Yes   2382202.0  1167202.0      81998.0
# 22              michigan      D   Yes   2804040.0  2649852.0      85410.0
# 23             minnesota      D   Yes   1717077.0  1484065.0      76029.0
# 24           mississippi      R   Yes    539508.0   756789.0      17597.0
# 25              missouri      R   Yes   1253014.0  1718736.0      54212.0
# 26               montana      R   Yes    244786.0   343602.0      15286.0
# 27              nebraska      R   Yes    374583.0   556846.0      20283.0
# 28                nevada      D   Yes    703486.0   669890.0      32000.0
# 29         new_hampshire      D   Yes    424921.0   365654.0      15607.0
# 30            new_jersey      D   Yes   2608335.0  1883274.0      57744.0
# 31            new_mexico      D   Yes    501614.0   401894.0      20457.0
# 32              new_york      D   Yes   5244886.0  3251997.0     119978.0
# 33        north_carolina      R   Yes   2684292.0  2758775.0      81737.0
# 34          north_dakota      R   Yes    114902.0   235595.0      11322.0
# 35                  ohio      R   Yes   2679165.0  3154834.0      88203.0
# 36              oklahoma      R   Yes    503890.0  1020280.0      36529.0
# 37                oregon      D   Yes   1340383.0   958448.0      75490.0
# 38          pennsylvania      D   Yes   3458229.0  3377674.0      79380.0
# 39          rhode_island      D   Yes    307486.0   199922.0      10349.0
# 40        south_carolina      R   Yes   1091541.0  1385103.0      36685.0
# 41          south_dakota      R   Yes    150471.0   261043.0      11095.0
# 42             tennessee      R   Yes   1143711.0  1852475.0      57665.0
# 43                 texas      R   Yes   5259126.0  5890347.0     165583.0
# 44                  utah      R   Yes    560282.0   865140.0      62867.0
# 45               vermont      D   Yes    242820.0   112704.0      11904.0
# 46              virginia      D   Yes   2413568.0  1962430.0      84526.0
# 47            washington      D   Yes   2369612.0  1584651.0     133368.0
# 48         west_virginia      R   Yes    235984.0   545382.0      13286.0
# 49             wisconsin      D   Yes   1630866.0  1610184.0      56991.0
# 50               wyoming      R   Yes     73491.0   193559.0       9715.0
#
#     dem_percent  rep_percent  other_percent  dem_this_margin  ...  stateid  \
# 0         0.366        0.620          0.014           -0.255  ...       AL
# 1         0.428        0.528          0.044           -0.101  ...       AK
# 2         0.494        0.491          0.016            0.003  ...       AZ
# 3         0.348        0.624          0.028           -0.276  ...       AR
# 4         0.635        0.343          0.022            0.292  ...       CA
# 5         0.554        0.419          0.027            0.135  ...       CO
# 6         0.593        0.392          0.016            0.201  ...       CT
# 7         0.587        0.398          0.015            0.190  ...       DE
# 8         0.921        0.054          0.025            0.868  ...       DC
# 9         0.479        0.512          0.009           -0.034  ...       FL
# 10        0.495        0.493          0.012            0.002  ...       GA
# 11        0.637        0.343          0.020            0.295  ...       HI
# 12        0.331        0.639          0.030           -0.308  ...       ID
# 13        0.575        0.406          0.019            0.170  ...       IL
# 14        0.410        0.570          0.020           -0.161  ...       IN
# 15        0.449        0.531          0.020           -0.082  ...       IA
# 16        0.416        0.562          0.022           -0.147  ...       KS
# 17        0.362        0.621          0.018           -0.259  ...       KY
# 18        0.399        0.585          0.017           -0.186  ...       LA
# 19        0.531        0.440          0.029            0.091  ...       ME
# 20        0.654        0.322          0.025            0.332  ...       MD
# 21        0.656        0.321          0.023            0.335  ...       MA
# 22        0.506        0.478          0.015            0.028  ...       MI
# 23        0.524        0.453          0.023            0.071  ...       MN
# 24        0.411        0.576          0.013           -0.165  ...       MS
# 25        0.414        0.568          0.018           -0.154  ...       MO
# 26        0.405        0.569          0.025           -0.164  ...       MT
# 27        0.394        0.585          0.021           -0.192  ...       NE
# 28        0.501        0.477          0.023            0.024  ...       NV
# 29        0.527        0.454          0.019            0.074  ...       NH
# 30        0.573        0.414          0.013            0.159  ...       NJ
# 31        0.543        0.435          0.022            0.108  ...       NM
# 32        0.609        0.377          0.014            0.231  ...       NY
# 33        0.486        0.499          0.015           -0.013  ...       NC
# 34        0.318        0.651          0.031           -0.334  ...       ND
# 35        0.452        0.533          0.015           -0.080  ...       OH
# 36        0.323        0.654          0.023           -0.331  ...       OK
# 37        0.565        0.404          0.032            0.161  ...       OR
# 38        0.500        0.488          0.011            0.012  ...       PA
# 39        0.594        0.386          0.020            0.208  ...       RI
# 40        0.434        0.551          0.015           -0.117  ...       SC
# 41        0.356        0.618          0.026           -0.262  ...       SD
# 42        0.375        0.607          0.019           -0.232  ...       TN
# 43        0.465        0.521          0.015           -0.056  ...       TX
# 44        0.376        0.581          0.042           -0.205  ...       UT
# 45        0.661        0.307          0.032            0.354  ...       VT
# 46        0.541        0.440          0.019            0.101  ...       VA
# 47        0.580        0.388          0.033            0.192  ...       WA
# 48        0.297        0.686          0.017           -0.389  ...       WV
# 49        0.494        0.488          0.017            0.006  ...       WI
# 50        0.266        0.699          0.035           -0.434  ...       WY
#
# 41   3.0   4.0  4.0       46.0     430.0     168.0          NaN    -0.297933
# 42  11.0   6.0  2.0       47.0     670.0     360.0          NaN    -0.260057
# 43  38.0   3.0  0.0       48.0     444.0     471.0          NaN    -0.089994
# 44   6.0   2.0  3.0       49.0     225.0     266.0          NaN    -0.180793
# 45   3.0  10.0  6.0       50.0     873.0     134.0          NaN     0.264084
# 46  13.0   8.0  3.0       51.0     809.0     299.0          NaN     0.053212
# 47  12.0   1.0  5.0       53.0     128.0      58.0          NaN     0.157060
# 48   5.0   7.0  3.0       54.0     765.0     284.0          NaN    -0.420727
# 49  10.0   6.0  6.0       55.0     601.0     169.0          NaN    -0.007643
# 50   3.0   3.0  4.0       56.0     306.0     187.0          NaN    -0.462953
#
#     Total 2016 Votes
# 0          2123372.0
# 1           318608.0
# 2          2573165.0
# 3          1130635.0
# 4         14181595.0
# 5          2780220.0
# 6          1644920.0
# 7           441590.0
# 8           311268.0
# 9          9420039.0
# 10         4092373.0
# 11          428937.0
# 12          690255.0
# 13         5536424.0
# 14         2734958.0
# 15         1566031.0
# 16         1184402.0
# 17         1924149.0
# 18         2029032.0
# 19          747927.0
# 20         2781446.0
# 21         3325046.0
# 22         4799284.0
# 23         2944813.0
# 24         1209357.0
# 25         2808605.0
# 26          497147.0
# 27          844289.0
# 28         1125385.0
# 29          744158.0
# 30         3874046.0
# 31          798318.0
# 32         7721453.0
# 33         4741564.0
# 34          344360.0
# 35         5496487.0
# 36         1452992.0
# 37         2001336.0
# 38         6115402.0
# 39          464144.0
# 40         2103027.0
# 41          370093.0
# 42         2508027.0
# 43         8969226.0
# 44         1131430.0
# 45          315067.0
# 46         3982752.0
# 47         3365644.0
# 48          713051.0
# 49         2976150.0
# 50          255849.0
#
# [51 rows x 22 columns]

# %%
# merge all data to one dataframe

df = pd.merge(iija, population, how='left', on='State').dropna(axis=0, how='any').reset_index().drop(columns='index')
df = pd.merge(df, votes, how='left', on='State')

# %%
# clean the new dataframe

df = df.rename(columns={'Total (Billions)':'Billions'})
df = df.drop(columns=['Unnamed: 19','2016 Margin', 'Total 2016 Votes'])
df['per_capita'] = df['Billions']*1000000000/df['Population']

# %%
# continue to clean the new dataframe

df['per_capita'] = df['per_capita'].round(0)
df.sort_values(by ='per_capita', ascending=False).head(60)
df['called'] = df['called'].fillna('Territory (Non-Voting)')
df['called'] = df['called'].replace({'R':'Republican','D':'Democrat'})
df.rename(columns={'called':'Party'}, inplace=True)
df.head(20)
# Out:
#                    State  Billions  Population                   Party final  \
# 0                alabama    3.0000   5117850.0              Republican   Yes
# 1                 alaska    3.7000    734654.0              Republican   Yes
# 2         american_samoa    0.0686     55519.0  Territory (Non-Voting)   NaN
# 3                arizona    3.5000   7452073.0                Democrat   Yes
# 4               arkansas    2.8000   3069856.0              Republican   Yes
# 5             california   18.4000  39181667.0                Democrat   Yes
# 6               colorado    3.2000   5912240.0                Democrat   Yes
# 7            connecticut    2.5000   3641369.0                Democrat   Yes
# 8               delaware    0.7920   1035354.0                Democrat   Yes
# 9   district_of_columbia    1.1000    682559.0                Democrat   Yes
# 10               florida    8.2000  22929248.0              Republican   Yes
# 11               georgia    5.0000  11063669.0                Democrat   Yes
# 12                  guam    0.1426    159385.0  Territory (Non-Voting)   NaN
# 13                hawaii    1.0000   1434950.0                Democrat   Yes
# 14                 idaho    1.2000   1970497.0              Republican   Yes
# 15              illinois    8.4000  12633389.0                Democrat   Yes
# 16               indiana    3.4000   6881373.0              Republican   Yes
# 17                  iowa    2.4000   3214739.0              Republican   Yes
# 18                kansas    1.5000   2949749.0              Republican   Yes
# 19              kentucky    3.9000   4549953.0              Republican   Yes
#
#      dem_votes  rep_votes  other_votes  dem_percent  rep_percent  ...  \
# 0     849624.0  1441170.0      32488.0        0.366        0.620  ...
# 1     153778.0   189951.0      15801.0        0.428        0.528  ...
# 2          NaN        NaN          NaN          NaN          NaN  ...
# 3    1672143.0  1661686.0      53497.0        0.494        0.491  ...
# 4     423932.0   760647.0      34490.0        0.348        0.624  ...
# 5   11110250.0  6006429.0     384192.0        0.635        0.343  ...
# 6    1804352.0  1364607.0      87993.0        0.554        0.419  ...
# 7    1080831.0   714717.0      28309.0        0.593        0.392  ...
# 8     296268.0   200603.0       7475.0        0.587        0.398  ...
# 9     317323.0    18586.0       8447.0        0.921        0.054  ...
# 10   5297045.0  5668731.0     101680.0        0.479        0.512  ...
# 11   2473633.0  2461854.0      62229.0        0.495        0.493  ...
# 12         NaN        NaN          NaN          NaN          NaN  ...
# 13    366130.0   196864.0      11475.0        0.637        0.343  ...
# 14    287021.0   554119.0      26091.0        0.331        0.639  ...
# 15   3471915.0  2446891.0     114938.0        0.575        0.406  ...
# 16   1242413.0  1729516.0      61183.0        0.410        0.570  ...
# 17    759061.0   897672.0      34138.0        0.449        0.531  ...
# 18    570323.0   771406.0      30574.0        0.416        0.562  ...
# 19    772474.0  1326646.0      37648.0        0.362        0.621  ...
#
#     margin_shift  vote_change  stateid    EV     X    Y  State_num  Center_X  \
# 0          0.023        0.094       AL   9.0   6.0  1.0        1.0     674.0
# 1          0.047        0.128       AK   3.0   0.0  6.0        2.0     105.0
# 2            NaN          NaN      NaN   NaN   NaN  NaN        NaN       NaN
# 3          0.039        0.316       AZ  11.0   2.0  2.0        4.0     205.0
# 4         -0.007        0.078       AR   6.0   5.0  2.0        5.0     564.0
# 5         -0.009        0.234       CA  55.0   1.0  3.0        6.0      75.0
# 6          0.086        0.171       CO   9.0   3.0  3.0        8.0     330.0
# 7          0.064        0.109       CT   7.0  10.0  4.0        9.0     886.0
# 8          0.076        0.142       DE   3.0  11.0  3.0       10.0     853.0
# 9          0.000        0.106       DC   3.0   9.0  3.0       11.0     829.0
# 10        -0.022        0.175       FL  29.0   8.0  0.0       12.0     787.0
# 11         0.054        0.221       GA  16.0   7.0  1.0       13.0     734.0
# 12           NaN          NaN      NaN   NaN   NaN  NaN        NaN       NaN
# 13        -0.027        0.339       HI   4.0   0.0  0.0       15.0     272.0
# 14         0.010        0.256       ID   4.0   2.0  5.0       16.0     195.0
# 15        -0.001        0.090       IL  20.0   6.0  5.0       17.0     614.0
# 16         0.031        0.109       IN  11.0   6.0  4.0       18.0     669.0
# 17         0.012        0.080       IA   6.0   5.0  4.0       19.0     536.0
# 18         0.059        0.159       KS   6.0   4.0  2.0       20.0     457.0
# 19         0.039        0.111       KY   8.0   6.0  3.0       21.0     706.0
#
#     Center_Y  per_capita
# 0      424.0       586.0
# 1      512.0      5036.0
# 2        NaN      1236.0
# 3      374.0       470.0
# 4      386.0       912.0
# 5      283.0       470.0
# 6      284.0       541.0
# 7      190.0       687.0
# 8      258.0       765.0
# 9      264.0      1612.0
# 10     520.0       358.0
# 11     419.0       452.0
# 12       NaN       895.0
# 13     570.0       697.0
# 14     148.0       609.0
# 15     264.0       665.0
# 16     264.0       494.0
# 17     223.0       747.0
# 18     307.0       509.0
# 19     314.0       857.0
#
# [20 rows x 22 columns]

# %%
by_party = df.drop(columns=['State','final','dem_percent','rep_percent','other_percent','dem_this_margin','margin_shift','vote_change','stateid','X','Y','State_num','Center_X','Center_Y','per_capita']).groupby(by='Party').sum()
by_party['per_capita'] = by_party['Billions'] * 1000000000 / by_party['Population']
by_party = by_party.sort_values('per_capita', ascending=False).reset_index()
by_party
# Out:
#                     Party  Billions   Population   dem_votes   rep_votes  \
# 0              Republican   88.5000  145798706.0  28120451.0  36134140.0
# 1                Democrat  103.0959  190956346.0  53162465.0  38089229.0
# 2  Territory (Non-Voting)    1.4365    3578986.0         0.0         0.0
#
#    other_votes     EV  total_spending  pop_to_spending_ratio  per_capita
# 0    1092410.0  229.0    8.850000e+10           28391.168967  607.001272
# 1    1799031.0  304.0    1.030959e+11           17394.020333  539.892505
# 2          0.0    0.0    1.436500e+09            5380.139138  401.370668

# %%
all_pop = by_party.drop(columns = ['Party','per_capita']).sum()
all_pop = pd.DataFrame(all_pop).transpose()
all_pop['dem_per_capita'] = all_pop['Billions'] * 1000000000 / all_pop['dem_votes']
all_pop['rep_per_capita'] = all_pop['Billions'] * 1000000000 / all_pop['rep_votes']
all_pop
# Out:
#    Billions   Population   dem_votes   rep_votes  other_votes     EV  \
# 0  193.0324  340334038.0  81282916.0  74223369.0    2891441.0  533.0
#
#    dem_per_capita  rep_per_capita
# 0     2374.821297     2600.695746

# %%
palette = {
    'Republican':'red',
    'Democrat':'blue',
    'Territory (Non-Voting)':'gray',
}
fig, ax1 = plt.subplots(figsize=(8,5))

sns.barplot(
    data=by_party,
    y='Party',
    x='Billions',
    hue='Party',
    palette=palette,
    orient='h',
    ax=ax1
)

ax1.set_xlabel('Spending in Billions')
ax1.set_ylabel('Political Party')
ax1.set_title('IIJA: Total Spending By Party Receiving Electoral Votes')
# Out:
# Text(0.5, 1.0, 'IIJA: Total Spending By Party Receiving Electoral Votes')

# %%
by_party = df.groupby(by='Party')['Billions'].sum()
palette = {
    'Republican': 'red',
    'Democrat': 'blue',
    'Territory (Non-Voting)': 'gray',
}
fig, ax1 = plt.subplots(figsize=(8, 5))

def format_billions(pct, allvals):
    total = sum(allvals)
    value = pct * total / 100
    return f"${value:.1f}B"

ax1.pie(
    by_party.values,
    labels=by_party.index,
    colors=[palette[p] for p in by_party.index],
    startangle=90,
    autopct=lambda pct: format_billions(pct, by_party.values),
    labeldistance=1.1,
    pctdistance=0.75
)

ax1.set_title('IIJA: Total Spending By Party Receiving Electoral Votes')

plt.show()

# %%
by_party
# Out:
#                         Billions   Population   dem_votes   rep_votes  \
# Party
# Republican               88.5000  145798706.0  28120451.0  36134140.0
# Democrat                103.0959  190956346.0  53162465.0  38089229.0
# Territory (Non-Voting)    1.4365    3578986.0         0.0         0.0
#
#                         other_votes     EV  per_capita
# Party
# Republican                1092410.0  229.0  607.001272
# Democrat                  1799031.0  304.0  539.892505
# Territory (Non-Voting)          0.0    0.0  401.370668

# %%
fig, ax2 = plt.subplots(figsize=(8,5))

sns.barplot(
    data=by_party,
    y='Party',
    x='per_capita',
    hue='Party',
    palette=palette,
    orient='h'
)

ax2.set_xlabel('Spending Per Capita')
ax2.set_ylabel('Political Party')
ax2.set_title('IIJA: Total Spending Per Capita')
# Out:
# Text(0.5, 1.0, 'IIJA: Total Spending Per Capita')

# %%
fig, ax3 = plt.subplots(figsize=(10,18))

sns.barplot(
    data=df.sort_values(by='per_capita', ascending=False).reset_index(drop=True),
    y='State',
    x='per_capita',
    hue='Party',
    palette=palette,
    orient='h'
)

ax3.set_xlabel('Spending Per Capita')
ax3.set_ylabel('State')
ax3.set_title('IIJA: Spending Per Capita By State')
sns.move_legend(ax3,'center right')

# %%
df['total_spending'] = df['Billions']*1000000000
df['pop_to_spending_ratio'] = df['Billions']*1000000000/df['Population']
sns.scatterplot(
    data=df,
    x='dem_votes',
    y='rep_votes',
    hue='Party',
    palette=palette,
    size='per_capita',
    sizes=(20,300),
    alpha=0.7
)

ax = plt.gca()

lims = [
    min(ax.get_xlim()[0], ax.get_ylim()[0]),
    max(ax.get_xlim()[1], ax.get_ylim()[1])
]

ax.plot(lims, lims, linestyle='--', color='black', linewidth=1)
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_aspect('equal', adjustable='box')

# %%
fig, ax4 = plt.subplots(figsize=(10,18))

sns.barplot(
    data=df.sort_values(by='Billions', ascending=False).reset_index(drop=True),
    y='State',
    x='Billions',
    hue='Party',
    palette=palette,
    orient='h'
)

ax4.set_xlabel('Total Spending in Billions')
ax4.set_ylabel('State')
ax4.set_title('IIJA: Total Spending By State')
sns.move_legend(ax4,'center right')

# %%
fig, ax4 = plt.subplots(figsize=(10, 18))

sns.barplot(
    data=df.sort_values(by='Population', ascending=False).reset_index(drop=True),
    y='State',
    x='Population',
    hue='Party',
    palette=palette,
    orient='h'
)

ax4.set_xlabel('Population')
ax4.set_ylabel('State')
ax4.set_title('State Population')
sns.move_legend(ax4, 'center right')

# %%
sns.scatterplot(
    data=df,
    x='Population',
    y='total_spending',
    hue='Party',
    palette=palette,
    alpha=0.7
)

ax = plt.gca()



ax.set_xlabel('Total Spending')
ax.set_ylabel('Population')
ax.set_title('IIJA: Spending vs Population')

lims = [
    min(ax.get_xlim()[0], ax.get_ylim()[0]),
    max(ax.get_xlim()[1], ax.get_ylim()[1])
]

#ax.plot(lims, lims, linestyle='--', color='black', linewidth=1)
#ax.set_xlim(lims)
#ax.set_ylim(lims)
#ax.set_aspect('equal', adjustable='box')
